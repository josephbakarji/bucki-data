# %% [markdown]
# # Damped bead on a rotating hoop: SINDy
#
# From Sec. 3.5 in Strogatz.  Full equation:
# $$
# m R \ddot{\phi} = -b \dot{\phi} - m g \sin \phi + m R \omega^2 \sin \phi \cos \phi
# $$
#
# If we introduce nondimensionalizations
# $$
# \gamma = \frac{R \omega^2}{g} \hspace{2cm} \epsilon = \frac{m^2 g R}{b^2}  \hspace{2cm} T = \frac{b}{mg},
# $$
# the equation becomes
# $$
# \epsilon \frac{d^2 \phi}{d \tau^2} = - \frac{d \phi}{d \tau} - \sin \phi + \gamma \sin \phi \cos \phi.
# $$
# For $\epsilon \ll 1$ and $\gamma = \mathcal{O}(1)$, the system is overdamped and approximately first-order.  The system undergoes a pitchfork bifurcation at $\gamma = 1$.

# %%
import numpy as np
import numpy.random as rng

from scipy.integrate import odeint


# Matplotlib
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import rcParams
mpl.rc('text', usetex=True)
mpl.rc('font', family='serif')
mpl.rc('xtick', labelsize=14)
mpl.rc('ytick', labelsize=14)
mpl.rc('axes', labelsize=20)
mpl.rc('axes', titlesize=20)
mpl.rc('figure', figsize=(6, 4))
# %config InlineBackend.figure_format = 'retina'

from scipy import linalg

# %% [markdown]
# # Simulate dynamics
#
# $$
# m R \ddot{\phi} = -b \dot{\phi} - m g \sin \phi + m R^2 \omega \sin \phi \cos \phi
# $$

# %%
nsamples = int(20)

m = np.random.uniform(1, 2, nsamples)
R = np.random.uniform(1e-1, 30, nsamples)
b = np.random.uniform(1, 10, nsamples)
g = 9.8 + 0*np.random.random(nsamples)
w = np.random.uniform(1e-2, 1, nsamples)

P = np.vstack([m, R, b, g, w])

eps = m**2 * g * R / b**2
gam = R * w**2 / g
T = b/(m*g)

# %%
def rhs(y, p):
    m, R, b, g, w = p
    return np.array([y[1],
                     (-b*y[1]-m*g*np.sin(y[0])+m*R*w**2*np.sin(y[0])*np.cos(y[0]))/(m*R)])

def run_sim(p, phi0, t):
    return odeint(lambda y, t: rhs(y, p), phi0, t)

# %%
phi0 = 0.2*np.random.randn(nsamples, 2)
t = np.linspace(0, 50, 500)  # Dimensional time
dt = t[1]-t[0]

phi = np.zeros([nsamples, len(t)])
dphi = np.zeros([nsamples, len(t)])
ddphi = np.zeros([nsamples, len(t)])
for i in range(nsamples):
    y =  run_sim(P[:, i], phi0[i, :], t)
    phi[i, :] = y[:, 0]
    dphi[i, :] = y[:, 1]
    ddphi[i, :] = rhs(y.T, P[:, i])[1, :]

# %%
plt.figure(figsize=(8, 3))
plt.plot(t, phi.T, c='k', lw=0.5)
plt.xlabel(r'$t$')
plt.ylabel(r"$\phi$")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8, 3))
plt.plot(t, ddphi.T, c='k', lw=0.5)
plt.xlabel(r'$t$')
plt.ylabel(r"$\ddot{\phi}$")
plt.grid()
plt.show()

# %% [markdown]
# # Nullspace search

# %%
from itertools import compress, product, combinations

from math import isnan, isinf


# Very inefficient
def is_collinear(v1, v2):
    # Return True if v1 and v2 are collinear vectors
    r = v1/v2
    x = []
    for i, ri in enumerate(r):
        if np.isfinite(ri) and abs(ri) > 0:
            x.append(ri)
    if len(x)>0 and not np.any(np.array(x)-x[0]):
        return True
    else:
        return False

def number_exists(num, nondim):
    # Return True if num (or a collinear to it) already exists in list 
    if not np.any(num):
        return True
    # Ignore collinearity here to avoid having to define more "p_fns"
    """for discovered in nondim:
        if is_collinear(num, discovered):
            return True"""
    return False


def get_nondim_numbers(dim_matrix, degree, num_params, time_vec=None):
    """
    Returns all possible dimensionless numbers in nullspace up to degree.
    
    If time_vec is included, should give the dimensions of time in dim_matrix rows
        e.g. [0, 0, 1]
        In this case, also returns all possible timescales
    """
    all_combinations = np.array(list(product(*[range(-degree, degree+1)] * num_params)))
    idxsort = np.argsort(np.sum(np.abs(all_combinations), axis=1))
    all_combinations = all_combinations[idxsort]
    nondim_list = []
    timescale_list = []
    for i in range(all_combinations.shape[0]):
        pi_candidate = all_combinations[i, :]
        if not np.any(dim_matrix @ pi_candidate):
            if not number_exists(pi_candidate, nondim_list):
                nondim_list.append(pi_candidate)
        elif (time_vec is not None) and (not np.any( dim_matrix @ pi_candidate - time_vec )):
            if not number_exists(pi_candidate, timescale_list):
                timescale_list.append(pi_candidate)
    return nondim_list, timescale_list

# %%
# Dimension matrix: [L, M, T] x [m, R, b, g, w]
D = np.array([[0, 1, 0], [1, 0, 0], [1, 1, -1], [1, 0, -2], [0, 0, -1]]).T

# Parameter matrix
P = np.vstack([ np.repeat(m, len(t)),
                np.repeat(R, len(t)),
                np.repeat(b, len(t)),
                np.repeat(g, len(t)),
                np.repeat(w, len(t)) ]).T

time_vec = np.array([0, 0, 1])

nondim_list, timescale_list = get_nondim_numbers(D, 2, D.shape[1], time_vec=time_vec)

# %%
P.shape
# Out:
# (10000, 5)

# %%
R.shape
# Out:
# (20,)

# %%
len(t)
# Out:
# 500

# %% [markdown]
# # pySINDy optimizer and sympy

# %%
import sympy as sym

# Define candidate functions
q_fns = [lambda q: q[1],
         lambda q: q[0],
         lambda q: q[0]**2,
         lambda q: q[0]**3,
         lambda q: q[0]**4,
         lambda q: q[0]**5,
         lambda q: q[0]**6,
         lambda q: q[0]**7
        ]

p_fns = [lambda pi: 1+0*pi[0],
         lambda pi: pi[0],
         lambda pi: pi[1]]

# %%
def Theta(Q, Pi):
    return np.vstack(
    [
        [
            q_fns[m](Q)*p_fns[n](Pi) for m in range(len(q_fns))
        ]
        for n in range(len(p_fns))  # Loops over this first, so first M functions are g[0]
    ]).T

# %%
q_sym = sym.symbols('m, R, b, g, \omega')

# %%
phi.shape
# Out:
# (20, 500)

# %%
import pysindy as ps

def fit_all_dynamics(nondim_list, timescale_list, num_nondim, threshold, verbose=False):
    from IPython.display import display, Math
    
    input_combinations = list(combinations(nondim_list, num_nondim))
    loss_list = []
    param_list = []
    param_names = []
    for T_vec in timescale_list:
        print(T_vec)
        Pi_t = np.exp( np.log(P) @ T_vec ).T  # Timescale
        
        # Quantity of interest scaled by time
        q = np.vstack([phi.flatten(), Pi_t*dphi.flatten()])
        dq =  (Pi_t**2*ddphi.flatten())[:, None]

        for pi_vecs in input_combinations:
            
            # Compute dimensionless parameters
            Pi = np.exp( np.log(P) @ np.vstack(pi_vecs).T ).T
            
            # Fit SINDy model
            opt = ps.STLSQ(threshold=threshold, alpha=0.0, max_iter=5)
            lib = Theta(q, Pi)
            opt.fit(lib, dq)
            test_loss = linalg.norm(dq - lib @ opt.coef_.T)

            # Save results
            loss_list.append(test_loss)
            
            # Save this parameter combination
            test_params = [sym.prod(q_sym**T_vec)]
            test_params.append([sym.prod(q_sym**pi_vec) for pi_vec in pi_vecs])
            param_names.append(test_params)
            param_list.append( (T_vec, pi_vecs) )
            if verbose:
                display(Math(sym.latex(test_params)))
                print('test loss = ', test_loss)
                print('----------------------------')
    return param_list, param_names, loss_list

# %%
threshold = 1e-2
num_nondim=2
param_list, param_names, loss_list = fit_all_dynamics(nondim_list, timescale_list, num_nondim, threshold)
# Out:
# [ 0  0  0  0 -1]
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=3.09012e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.83399e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=9.97432e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.04812e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=3.95576e-18): result may not be accurate.
#   overwrite_a=True).T
# [ 1  1 -1  0  0]
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=5.54715e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=3.29918e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=4.32777e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.7933e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.9365e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=9.03206e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=4.84975e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=2.83945e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=7.1171e-19): result may not be accurate.
#   overwrite_a=True).T
# [-1  0  1 -1  0]
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.10793e-16): result may not be accurate.
#   overwrite_a=True).T
# [ 0  1  0 -1  1]
# [ 1  0 -1  1 -2]
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=9.70134e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.02383e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.38149e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=4.66303e-21): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=6.49242e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.22006e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.72393e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=2.78286e-21): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=8.07746e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=3.65408e-20): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=5.24559e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=3.17262e-19): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.53691e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=6.16232e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=5.61213e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.98671e-19): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=3.11715e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=5.58125e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.51237e-20): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=2.12624e-19): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.63618e-21): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=9.13878e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=7.61637e-20): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=2.14264e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=2.53797e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=5.25761e-19): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=4.08208e-20): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=2.33518e-20): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=6.01265e-22): result may not be accurate.
#   overwrite_a=True).T
# [-1 -1  1  0 -2]
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=5.53693e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=9.95313e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=4.95463e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=3.50104e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=2.13255e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.10324e-16): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=4.49244e-17): result may not be accurate.
#   overwrite_a=True).T
# [ 1  2 -1 -1  2]
# [-1  1  1 -2  2]
# [-2  0  2 -2  1]
# /home/jared/.local/lib/python3.6/site-packages/pysindy/optimizers/stlsq.py:172: ConvergenceWarning: STLSQ._reduce did not converge after 5 iterations.
#   ConvergenceWarning,
# /home/jared/.local/lib/python3.6/site-packages/pysindy/optimizers/stlsq.py:172: ConvergenceWarning: STLSQ._reduce did not converge after 5 iterations.
#   ConvergenceWarning,
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.10725e-16): result may not be accurate.
#   overwrite_a=True).T
# [-2 -1  2 -1 -1]
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.10302e-16): result may not be accurate.
#   overwrite_a=True).T
# [ 2  2 -2  0  1]
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=9.99909e-19): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=5.92554e-19): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=7.77635e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=6.75024e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=4.23218e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=3.2221e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=4.40796e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=3.48136e-19): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.62368e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.08845e-16): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=8.7155e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=5.30929e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.2785e-19): result may not be accurate.
#   overwrite_a=True).T
# [ 2  1 -2  1 -1]
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.7895e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.84361e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=2.48777e-19): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=8.3892e-22): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.19752e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=2.19416e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=3.09892e-19): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=5.00087e-22): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=2.97688e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=2.52449e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.44864e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=6.56057e-21): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=7.00272e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=9.67669e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=5.59816e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=5.69761e-20): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=2.8241e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.10914e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.00781e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=2.03733e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=3.5696e-20): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=2.94992e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=2.63935e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=5.59968e-19): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.00275e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=2.72091e-21): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=7.18859e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=3.8204e-20): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=2.93539e-22): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.64478e-17): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.36922e-20): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=3.85857e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=4.65802e-18): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=9.43964e-20): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=7.35412e-21): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=4.278e-21): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.07907e-22): result may not be accurate.
#   overwrite_a=True).T
# /home/jared/.local/lib/python3.6/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=5.67523e-17): result may not be accurate.
#   overwrite_a=True).T

# %%
from IPython.display import display, Math
sort_idx = np.argsort(loss_list)

for i in range(5):
    display(Math(sym.latex(param_names[sort_idx[i]])))
    print('test loss = ', loss_list[sort_idx[i]])
    print('----------------------------')
# Out:
# $\displaystyle \left[ \frac{b}{g m}, \  \left[ \frac{b^{2}}{R g m^{2}}, \  \frac{\omega^{2} b^{2}}{g^{2} m^{2}}\right]\right]$
# test loss =  0.0027576214210716303
# ----------------------------
# $\displaystyle \left[ \frac{\omega b^{2}}{g^{2} m^{2}}, \  \left[ \frac{b^{2}}{R g m^{2}}, \  \frac{\omega^{2} b^{2}}{g^{2} m^{2}}\right]\right]$
# test loss =  0.026200987938883615
# ----------------------------
# $\displaystyle \left[ \frac{\omega b^{2}}{g^{2} m^{2}}, \  \left[ \frac{R \omega^{2}}{g}, \  \frac{\omega^{2} b^{2}}{g^{2} m^{2}}\right]\right]$
# test loss =  0.02784810915893492
# ----------------------------
# $\displaystyle \left[ \frac{\omega b^{2}}{g^{2} m^{2}}, \  \left[ \frac{\omega b}{g m}, \  \frac{\omega^{2} b^{2}}{g^{2} m^{2}}\right]\right]$
# test loss =  0.02850753543492441
# ----------------------------
# $\displaystyle \left[ \frac{\omega b^{2}}{g^{2} m^{2}}, \  \left[ \frac{b}{R \omega m}, \  \frac{\omega^{2} b^{2}}{g^{2} m^{2}}\right]\right]$
# test loss =  0.03307216322881329
# ----------------------------

# %% [markdown]
# Repeat for the best solution

# %%
model_idx = 0
T_vec = param_list[sort_idx[model_idx]][0]
pi_vec = param_list[sort_idx[model_idx]][1]

Pi_t = np.exp( np.log(P) @ T_vec ).T  # Timescale

# Quantity of interest scaled by time
q = np.vstack([phi.flatten(), Pi_t*dphi.flatten()])
dq =  (Pi_t**2*ddphi.flatten())[:, None]

# Compute dimensionless parameters
Pi = np.exp( np.log(P) @ np.vstack(pi_vec).T ).T

# Fit SINDy model
# Cubic terms
opt = ps.STLSQ(threshold=1e-1, alpha=0.00, max_iter=5)
lib = Theta(q, Pi)
opt.fit(lib, dq)
Xi3 = opt.coef_[0, :]

# Septic terms
opt = ps.STLSQ(threshold=5e-3, alpha=0.00, max_iter=5)
lib = Theta(q, Pi)
opt.fit(lib, dq)
Xi7 = opt.coef_[0, :]

# %%
lib = Theta(sym.symbols('q, \dot{q}'), sym.symbols('\pi_1, \pi_2')).flatten('F')
model = lib @ Xi3
model
# Out:
# -0.906460483010763*\dot{q}*\pi_1 + 0.146283918287287*\pi_1*q**3 - 0.920164192439404*\pi_1*q - 0.421360830407183*\pi_2*q**3 + 0.847784754751953*\pi_2*q

# %% [markdown]
# ### Evaluate model for out-of-sample parameters

# %%
m = np.random.uniform(1, 2)
R = np.random.uniform(1e-1, 100)
b = np.random.uniform(1, 10)
g = 9.8
w = np.random.uniform(1e-2, 4)

# Difficult test case
m = 1.95
R = 34.8
b = 2.00
g = 9.8
w = 0.58
P_test = np.vstack([m, R, b, g, w])

# %%
# gamma, eps, T
R*w**2/g, m**2*g*R/b**2, b/m*g
# Out:
# (1.1945632653061222, 324.20115, 10.051282051282053)

# %%
model_idx = 0
T_vec, pi_vec = param_list[sort_idx[model_idx]]

Pi_t = np.exp( np.log(P_test).T @ T_vec )[0]  # Timescale
# Compute dimensionless parameters
Pi = np.exp( np.vstack(pi_vec) @ np.log(P_test) )

# %%
q_sym = sym.symbols('q, \dot{q}')
lib = Theta(q_sym, Pi).flatten('F')

t = np.linspace(0, 300, 500)  # Dimensional time
phi0_test = [1, -0.2]
phi0_nondim = phi0_test.copy()
phi0_nondim[1] *= Pi_t
phi_test = run_sim(P_test[:, 0], phi0_test, t)[:, 0]

rhs_sindy = sym.lambdify(q_sym, lib @ Xi3)
phi_sindy3 = odeint(lambda y, t: np.array([y[1], rhs_sindy(*y)]),
             phi0_nondim, t/Pi_t)[:, 0]

rhs_sindy = sym.lambdify(q_sym, lib @ Xi7)
phi_sindy7 = odeint(lambda y, t: np.array([y[1], rhs_sindy(*y)]),
             phi0_nondim, t/Pi_t)[:, 0]

plt.figure(figsize=(8, 3))
plt.plot(t, phi_test, c='k', lw=2, label='Test case')
plt.plot(t, phi_sindy3, lw=2, ls='--', label='SINDy (cubic)')
#plt.plot(t, phi_sindy7, lw=2, ls='--', label='SINDy (septic)')
plt.legend(fontsize=14)
plt.xlabel("$t$")
plt.ylabel(r"$\phi$")
plt.grid()

# %% [markdown]
# # TODO:
#
# * pySINDy compatibility for SR3
# * Define class to be compatible with Joe's package
# * ~~Use sympy to print expressions~~
# * Clean example notebook
